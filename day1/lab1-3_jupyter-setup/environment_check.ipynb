# %% [markdown]
# # Lab 1-3: 환경 확인 및 KFP SDK 설치
#
# 이 노트북에서는 Kubeflow Jupyter 환경을 확인하고 필요한 패키지를 설치합니다.

# %% [markdown]
# ## 1. Python 환경 확인

# %%
import sys
print(f"Python Version: {sys.version}")
print(f"Python Executable: {sys.executable}")

# %% [markdown]
# ## 2. 주요 패키지 버전 확인

# %%
import numpy as np
import pandas as pd
import sklearn

print(f"NumPy: {np.__version__}")
print(f"Pandas: {pd.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")

# %% [markdown]
# ## 3. Kubernetes 환경 확인

# %%
import os

print("=" * 50)
print("Kubernetes Environment Variables")
print("=" * 50)
print(f"Hostname: {os.getenv('HOSTNAME', 'N/A')}")
print(f"Home Directory: {os.getenv('HOME', 'N/A')}")
print(f"Namespace: {os.getenv('NAMESPACE', 'N/A')}")

# %% [markdown]
# ## 4. KFP SDK 설치

# %%
# KFP SDK 설치
# !pip install kfp==1.8.22 -q
print("✅ KFP SDK 설치 완료!")

# %%
# 설치 확인
import kfp
from kfp import dsl
from kfp.components import create_component_from_func

print(f"KFP Version: {kfp.__version__}")
print("✅ KFP SDK 사용 준비 완료!")

# %% [markdown]
# ## 5. MLflow 설치 (선택)

# %%
# MLflow 설치
# !pip install mlflow==2.9.2 -q
print("✅ MLflow 설치 완료!")

# %%
# 설치 확인
import mlflow
print(f"MLflow Version: {mlflow.__version__}")

# %% [markdown]
# ## 6. 환경 검증 완료
#
# 모든 패키지가 정상적으로 설치되었습니다!
#
# 다음 실습(Lab 1-4)으로 진행하세요.

# %%
print("="*50)
print("✅ Lab 1-3 환경 설정 완료!")
print("="*50)
print("\n다음 단계: Lab 1-4 Hello World Pipeline")
